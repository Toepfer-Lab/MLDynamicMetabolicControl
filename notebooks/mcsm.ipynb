# %%
import micom
from micom import Community
from micom import load_pickle
import pandas as pd
import cobra

# %%
cobra.Configuration.solver = 'cplex'

# %%
MODEL_DIR = "/home/jkaatz/MA/MLDynamicMetabolicControl/model/dcom.pickle"

comm = load_pickle(MODEL_DIR)

# %%
import sys, os
print("Python:", sys.version)
print("PYTHONPATH:", os.environ.get('PYTHONPATH', 'NOT SET'))
print("CPLEX_STUDIO_DIR:", os.environ.get('CPLEX_STUDIO_DIR', 'NOT SET'))
print()
# check if the cplex path is actually in sys.path
for p in sys.path:
    if 'cplex' in p.lower() or 'CPLEX' in p:
        print("Found CPLEX in sys.path:", p)
# Out:
# Python: 3.9.21 (main, Aug 19 2025, 00:00:00)
# [GCC 11.5.0 20240719 (Red Hat 11.5.0-5)]
# PYTHONPATH: /projects/sw/eb/lib/python3.9/site-packages:/projects/sw/eb/lib/python3.9/site-packages:/projects/sw/eb/lib/python3.9/site-packages:
# CPLEX_STUDIO_DIR: NOT SET
